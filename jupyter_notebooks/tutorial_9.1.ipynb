# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import os;
import tensorflow as tf;
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
sns.set_style('whitegrid')

# %%
data = fetch_california_housing()
df = pd.DataFrame(data.data,columns=data.feature_names)
df['price'] = pd.Series(data.target)
print(df.shape)
df.head()

# %% [markdown]
# ##### Split Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                    df.drop(['price'],axis=1),
                                    df['price'],
                                    test_size=0.2,
                                    random_state=0
                                    )
print("* Train set:", X_train.shape, y_train.shape, "\n* Test set:",  X_test.shape, y_test.shape)

# %%
X_train, X_val, y_train, y_val = train_test_split(
                                    X_train,
                                    y_train,
                                    test_size=0.2,
                                    random_state=0
                                    )

print("* Train set:", X_train.shape, y_train.shape)
print("* Validation set:",  X_val.shape, y_val.shape)
print("* Test set:",   X_test.shape, y_test.shape)

# %% [markdown]
# ### Pipeline for data processing

# %%
def pipeline_pre_processing():
    """
    Define data preparation pipeline
    """
    pipeline_base = Pipeline([

      ( "feat_scaling", StandardScaler() )

    ])
    return pipeline_base

# %%
pipeline = pipeline_pre_processing()
X_train = pipeline.fit_transform(X_train)
X_val= pipeline.transform(X_val)
X_test = pipeline.transform(X_test)

# %%
def create_tf_model(n_features):

  model = Sequential()
  model.add(Dense(units=n_features, activation='relu', input_shape=(n_features,)))

  model.add(Dense(units=8,activation='relu'))
  model.add(Dropout(0.25))

  model.add(Dense(units=4,activation='relu'))
  model.add(Dropout(0.25))

  model.add(Dense(units=1))
  model.compile(loss='mse', optimizer='adam')

  return model

# %%
model = create_tf_model(n_features=X_train.shape[1])
model.summary()

# %% [markdown]
# ### Fitting the model

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)

# %%
model.fit(x=X_train,
          y=y_train,
          epochs=100,
          validation_data=(X_val, y_val),
          verbose=1,
          callbacks=[early_stop]
          )
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5811 - val_loss: 0.4099
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5806 - val_loss: 0.4157
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5824 - val_loss: 0.4206
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5988 - val_loss: 0.4070
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5701 - val_loss: 0.4145
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5775 - val_loss: 0.4183
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5818 - val_loss: 0.4074
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6135 - val_loss: 0.4114
# Epoch 9/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5685 - val_loss: 0.4145
# Epoch 10/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5852 - val_loss: 0.4108
# Epoch 11/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5968 - val_loss: 0.4169
# Epoch 12/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5902 - val_loss: 0.4029
# Epoch 13/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5930 - val_loss: 0.3958
# Epoch 14/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5628 - val_loss: 0.4127
# Epoch 15/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5744 - val_loss: 0.3992
# Epoch 16/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5919 - val_loss: 0.4222
# Epoch 17/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5982 - val_loss: 0.4172
# Epoch 18/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5633 - val_loss: 0.4117
# Epoch 19/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6022 - val_loss: 0.3996
# Epoch 20/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5725 - val_loss: 0.4187
# Epoch 21/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5856 - val_loss: 0.4097
# Epoch 22/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5946 - val_loss: 0.4092
# Epoch 23/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5998 - val_loss: 0.3922
# Epoch 24/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5912 - val_loss: 0.4090
# Epoch 25/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5658 - val_loss: 0.4120
# Epoch 26/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5698 - val_loss: 0.4153
# Epoch 27/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5850 - val_loss: 0.4034
# Epoch 28/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5852 - val_loss: 0.4128
# Epoch 29/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5749 - val_loss: 0.4109
# Epoch 30/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5703 - val_loss: 0.4066
# Epoch 31/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6018 - val_loss: 0.4098
# Epoch 32/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5748 - val_loss: 0.4047
# Epoch 33/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5728 - val_loss: 0.4098
# Epoch 34/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5985 - val_loss: 0.3984
# Epoch 35/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5849 - val_loss: 0.3973
# Epoch 36/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5840 - val_loss: 0.4323
# Epoch 37/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5833 - val_loss: 0.4033
# Epoch 38/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5645 - val_loss: 0.4093
# Epoch 38: early stopping

# %% [markdown]
# ### Model evaluation

# %%
losses = pd.DataFrame(model.history.history)
losses
# Out:
#         loss  val_loss
# 0   0.579256  0.409922
# 1   0.587554  0.415726
# 2   0.603738  0.420597
# 3   0.593869  0.407034
# 4   0.579393  0.414485
# 5   0.588834  0.418282
# 6   0.587503  0.407386
# 7   0.599050  0.411368
# 8   0.588805  0.414527
# 9   0.579127  0.410754
# 10  0.595992  0.416867
# 11  0.590260  0.402916
# 12  0.586076  0.395824
# 13  0.581695  0.412673
# 14  0.591424  0.399244
# 15  0.585400  0.422229
# 16  0.588658  0.417164
# 17  0.574945  0.411654
# 18  0.586264  0.399639
# 19  0.574795  0.418717
# 20  0.584568  0.409746
# 21  0.590123  0.409194
# 22  0.582838  0.392153
# 23  0.591552  0.408982
# 24  0.584230  0.411983
# 25  0.574688  0.415336
# 26  0.583427  0.403425
# 27  0.581769  0.412759
# 28  0.587180  0.410945
# 29  0.585195  0.406639
# 30  0.580613  0.409775
# 31  0.585801  0.404746
# 32  0.575079  0.409752
# 33  0.590751  0.398352
# 34  0.582790  0.397294
# 35  0.582586  0.432336
# 36  0.588037  0.403301
# 37  0.574236  0.409313

# %%
sns.set_style("whitegrid")
losses[['loss','val_loss']].plot(style='.-')
plt.title("Loss")
plt.show()

# %%
model.evaluate(X_test,y_test)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.4198
# 0.39916345477104187

# %%
def regression_performance(X_train, y_train,
                           X_val, y_val,
                           X_test, y_test,pipeline):
    """
    Assessment of performance of CNN regression model
    """
    print("Model Evaluation \n")
    print("* Train Set")
    regression_evaluation(X_train,y_train,pipeline)
    print("* Validation Set")
    regression_evaluation(X_val, y_val,pipeline)
    print("* Test Set")
    regression_evaluation(X_test,y_test,pipeline)

def regression_evaluation(X, y, pipeline):
    """
    Gets features and target (either from train or test set) and pipeline.
    - Predicts using the pipeline and the features
    - Calculates performance metrics comparing the prediction to the target
    """
    prediction = pipeline.predict(X)
    print('R2 Score:', round(r2_score(y, prediction), 3))
    print('Mean Absolute Error:', round(mean_absolute_error(y, prediction), 3))
    print('Mean Squared Error:', round(mean_squared_error(y, prediction), 3))
    print('Root Mean Squared Error:', round(np.sqrt(mean_squared_error(y, prediction)), 3))
    print("\n")
    

def regression_evaluation_plots(X_train, y_train,
                                X_val, y_val,
                                X_test, y_test,
                                pipeline, alpha_scatter=0.5):
    """
    Plot regression evaluation
    """
    pred_train = pipeline.predict(X_train).reshape(-1)
    # we reshape the prediction arrays to be in the format (n_rows,), so we can plot it after
    pred_val = pipeline.predict(X_val).reshape(-1)
    pred_test = pipeline.predict(X_test).reshape(-1)
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,6))
    
    sns.scatterplot(x=y_train , y=pred_train, alpha=alpha_scatter, ax=axes[0])
    
    sns.lineplot(x=y_train , y=y_train, color='red', ax=axes[0])
    axes[0].set_xlabel("Actual")
    axes[0].set_ylabel("Predictions")
    axes[0].set_title("Train Set")
    
    sns.scatterplot(x=y_val , y=pred_val, alpha=alpha_scatter, ax=axes[1])
    
    sns.lineplot(x=y_val , y=y_val, color='red', ax=axes[1])
    axes[1].set_xlabel("Actual")
    axes[1].set_ylabel("Predictions")
    axes[1].set_title("Validation Set")
    
    sns.scatterplot(x=y_test , y=pred_test, alpha=alpha_scatter, ax=axes[2])
    sns.lineplot(x=y_test , y=y_test, color='red', ax=axes[2])
    axes[2].set_xlabel("Actual")
    axes[2].set_ylabel("Predictions")
    axes[2].set_title("Test Set")
    
    plt.show()

# %%
regression_performance(X_train, y_train,X_val, y_val, X_test, y_test,model)
regression_evaluation_plots(X_train, y_train, X_val, y_val,X_test, y_test,
                            model, alpha_scatter=0.5)
# Out:
# Model Evaluation
#
# * Train Set
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# R2 Score: 0.701
# Mean Absolute Error: 0.465
# Mean Squared Error: 0.4
# Root Mean Squared Error: 0.632
#
#
# * Validation Set
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# R2 Score: 0.693
# Mean Absolute Error: 0.469
# Mean Squared Error: 0.409
# Root Mean Squared Error: 0.64
#
#
# * Test Set
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# R2 Score: 0.694
# Mean Absolute Error: 0.466
# Mean Squared Error: 0.399
# Root Mean Squared Error: 0.632
#
#
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step

# %% [markdown]
# ### Prediction

# %%
X_test.shape
# Out:
# (4128, 8)

# %%
live_data = X_test[54:55,:]
live_data
# Out:
# array([[-1.2449854 , -0.20116759, -1.69946574, -0.09213495, -0.2003886 ,
#          0.14367436, -0.73320429,  0.64473104]])

# %%
model.predict(live_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# array([[1.7966146]], dtype=float32)

# %%
sample = pd.DataFrame({
    'MedInc': [8.325200],
    'HouseAge': [41.000000],
    'AveRooms': [6.984127],
    'AveBedrms': [1.023810],
    'Population': [322.000000],
    'AveOccup': [2.555556],
    'Latitude': [37.880000],
    'Longitude': [-122.230000] 
})

sample
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127    1.02381       322.0  2.555556     37.88
#
#    Longitude
# 0    -122.23

# %%
sample_cnn = pipeline.transform(sample.values)
sample_cnn
# Out:
# /home/codeany/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 2.33427752,  0.99158883,  0.69465782, -0.1578881 , -0.98629534,
#         -0.08184656,  1.04783331, -1.3256435 ]])

# %%
predicted_price = model.predict(sample_cnn)[0][0]
print('---------------')
print(f"Predicted house price based on the information provided is: {predicted_price:.2f} arb. units.")
print('---------------')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ---------------
# Predicted house price based on the information provided is: 3.69 arb. units.
# ---------------

# %%
model.save('../data/nn_regression.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
